# %% [markdown]
# ### dataframe manipulation and accsing

# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
df3=pd.read_html('https://currentaffairs.adda247.com/states-and-capitals/')
df1=df3[0]

# %%
df1
# Out:
#     S.NO              State             Capital                     CM  \
# 0      1     Andhra Pradesh           Amaravati   YS Jagan Mohan Reddy
# 1      2  Arunachal Pradesh            Itanagar            Pema Khandu
# 2      3              Assam              Dispur    Himanta Biswa Sarma
# 3      4              Bihar               Patna           Nitish Kumar
# 4      5       Chhattisgarh              Raipur         Bhupesh Baghel
# 5      6                Goa              Panaji          Pramod Sawant
# 6      7            Gujarat         Gandhinagar        Bhupendra Patel
# 7      8            Haryana          Chandigarh            Manohar Lal
# 8      9   Himachal Pradesh              Shimla          Jairam Thakur
# 9     10          Jharkhand              Ranchi           Hemant Soren
# 10    11          Karnataka           Bengaluru       Basavaraj Bommai
# 11    12             Kerala  Thiruvananthapuram       Pinarayi Vijayan
# ...

# %% [markdown]
# ### using loc(locate) function on data frame

# %%
df1.loc[:,['State','CM']]
# Out:
#                 State                     CM
# 0      Andhra Pradesh   YS Jagan Mohan Reddy
# 1   Arunachal Pradesh            Pema Khandu
# 2               Assam    Himanta Biswa Sarma
# 3               Bihar           Nitish Kumar
# 4        Chhattisgarh         Bhupesh Baghel
# 5                 Goa          Pramod Sawant
# 6             Gujarat        Bhupendra Patel
# 7             Haryana            Manohar Lal
# 8    Himachal Pradesh          Jairam Thakur
# 9           Jharkhand           Hemant Soren
# 10          Karnataka       Basavaraj Bommai
# 11             Kerala       Pinarayi Vijayan
# 12     Madhya Pradesh  Shivraj Singh Chouhan
# 13        Maharashtra          Eknath Shinde
# 14            Manipur         N. Biren Singh
# 15          Meghalaya  Conrad Kongkal Sangma
# 16            Mizoram         Pu Zoramthanga
# 17           Nagaland            Neiphiu Rio
# 18             Odisha         Naveen Patnaik
# 19             Punjab    Bhagwant Singh Mann
# ...

# %% [markdown]
#  ### Using iloc( index using location ) in data frames

# %%
df1.iloc[:,[1,2,3]]
# Out:
#                 State             Capital                     CM
# 0      Andhra Pradesh           Amaravati   YS Jagan Mohan Reddy
# 1   Arunachal Pradesh            Itanagar            Pema Khandu
# 2               Assam              Dispur    Himanta Biswa Sarma
# 3               Bihar               Patna           Nitish Kumar
# 4        Chhattisgarh              Raipur         Bhupesh Baghel
# 5                 Goa              Panaji          Pramod Sawant
# 6             Gujarat         Gandhinagar        Bhupendra Patel
# 7             Haryana          Chandigarh            Manohar Lal
# 8    Himachal Pradesh              Shimla          Jairam Thakur
# 9           Jharkhand              Ranchi           Hemant Soren
# 10          Karnataka           Bengaluru       Basavaraj Bommai
# 11             Kerala  Thiruvananthapuram       Pinarayi Vijayan
# 12     Madhya Pradesh              Bhopal  Shivraj Singh Chouhan
# ...

# %% [markdown]
# ## rows operation on loc

# %%
df1.loc[:5,['State','CM']]
# Out:
#                State                    CM
# 0     Andhra Pradesh  YS Jagan Mohan Reddy
# 1  Arunachal Pradesh           Pema Khandu
# 2              Assam   Himanta Biswa Sarma
# 3              Bihar          Nitish Kumar
# 4       Chhattisgarh        Bhupesh Baghel
# 5                Goa         Pramod Sawant

# %% [markdown]
# ## rows using iloc

# %%
df1.iloc[:10,[1,2,3]]
# Out:
#                State      Capital                    CM
# 0     Andhra Pradesh    Amaravati  YS Jagan Mohan Reddy
# 1  Arunachal Pradesh     Itanagar           Pema Khandu
# 2              Assam       Dispur   Himanta Biswa Sarma
# 3              Bihar        Patna          Nitish Kumar
# 4       Chhattisgarh       Raipur        Bhupesh Baghel
# 5                Goa       Panaji         Pramod Sawant
# 6            Gujarat  Gandhinagar       Bhupendra Patel
# 7            Haryana   Chandigarh           Manohar Lal
# 8   Himachal Pradesh       Shimla         Jairam Thakur
# 9          Jharkhand       Ranchi          Hemant Soren

# %%
df1.loc[20::-1,['State','CM']]
# Out:
#                 State                     CM
# 20          Rajasthan           Ashok Gehlot
# 19             Punjab    Bhagwant Singh Mann
# 18             Odisha         Naveen Patnaik
# 17           Nagaland            Neiphiu Rio
# 16            Mizoram         Pu Zoramthanga
# 15          Meghalaya  Conrad Kongkal Sangma
# 14            Manipur         N. Biren Singh
# 13        Maharashtra          Eknath Shinde
# 12     Madhya Pradesh  Shivraj Singh Chouhan
# 11             Kerala       Pinarayi Vijayan
# 10          Karnataka       Basavaraj Bommai
# 9           Jharkhand           Hemant Soren
# 8    Himachal Pradesh          Jairam Thakur
# 7             Haryana            Manohar Lal
# 6             Gujarat        Bhupendra Patel
# 5                 Goa          Pramod Sawant
# 4        Chhattisgarh         Bhupesh Baghel
# 3               Bihar           Nitish Kumar
# 2               Assam    Himanta Biswa Sarma
# 1   Arunachal Pradesh            Pema Khandu
# ...

# %%
df1.iloc[-1,]
# Out:
# S.NO                     28
# State           West Bengal
# Capital             Kolkata
# CM          Mamata Banerjee
# Governor        La. Ganesan
# Name: 27, dtype: object

# %% [markdown]
# ### operation on frames

# %%
df1.shape
# Out:
# (28, 5)

# %%
r,c=df1.shape

# %%
r
c
# Out:
# 5

# %% [markdown]
# ### head a nd tail functions in pandas will retrive 5 rows only

# %%
df1.head()
# Out:
#    S.NO              State    Capital                    CM  \
# 0     1     Andhra Pradesh  Amaravati  YS Jagan Mohan Reddy
# 1     2  Arunachal Pradesh   Itanagar           Pema Khandu
# 2     3              Assam     Dispur   Himanta Biswa Sarma
# 3     4              Bihar      Patna          Nitish Kumar
# 4     5       Chhattisgarh     Raipur        Bhupesh Baghel
#
#                    Governor
# 0  Biswa Bhusan Harichandan
# 1              B. D. Mishra
# 2             Jagdish Mukhi
# 3             Phagu Chauhan
# 4     Sushri Anusuiya Uikey

# %%
df1.tail()
# Out:
#     S.NO          State    Capital                   CM  \
# 23    24      Telangana  Hyderabad  K Chandrasekhar Rao
# 24    25        Tripura   Agartala     Biplab Kumar Deb
# 25    26  Uttar Pradesh    Lucknow     Yogi Aditya Nath
# 26    27    Uttarakhand   Dehradun  Pushkar Singh Dhami
# 27    28    West Bengal    Kolkata      Mamata Banerjee
#
#                    Governor
# 23  Tamilisai Soundararajan
# 24     Satyadeo Narain Arya
# 25          Anandiben Patel
# 26    Lt. Gen. Gurmit Singh
# 27              La. Ganesan

# %% [markdown]
# ## we can use mathmatical functions also
# like min(),describe()

# %%
df1['S.NO'].min()
# Out:
# 1

# %%
df1['S.NO'].max()
# Out:
# 28

# %% [markdown]
# ### df.describe()will give us stastical informqation all things

# %%
df2=pd.read_csv(r'C:\\Users\chava\Desktop\New folder\python\pandas\test3.csv')

# %%
df2.head
# Out:
# <bound method NDFrame.head of      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     65  Female              0.7               0.1                   187
# 1     62    Male             10.9               5.5                   699
# 2     62    Male              7.3               4.1                   490
# 3     58    Male              1.0               0.4                   182
# 4     72    Male              3.9               2.0                   195
# ..   ...     ...              ...               ...                   ...
# 578   60    Male              0.5               0.1                   500
# 579   40    Male              0.6               0.1                    98
# 580   52    Male              0.8               0.2                   245
# 581   31    Male              1.3               0.5                   184
# 582   38    Male              1.0               0.3                   216
#
# ...

# %%
df2.describe()
# Out:
#               Age  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# count  583.000000       583.000000        583.000000            583.000000
# mean    44.746141         3.298799          1.486106            290.576329
# std     16.189833         6.209522          2.808498            242.937989
# min      4.000000         0.400000          0.100000             63.000000
# 25%     33.000000         0.800000          0.200000            175.500000
# 50%     45.000000         1.000000          0.300000            208.000000
# 75%     58.000000         2.600000          1.300000            298.000000
# max     90.000000        75.000000         19.700000           2110.000000
#
#        Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# count                583.000000                  583.000000      583.000000
# mean                  80.713551                  109.910806        6.483190
# ...

# %% [markdown]
# # performing quries on data frames

# %%
df2[df2.Age>55]
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     65  Female              0.7               0.1                   187
# 1     62    Male             10.9               5.5                   699
# 2     62    Male              7.3               4.1                   490
# 3     58    Male              1.0               0.4                   182
# 4     72    Male              3.9               2.0                   195
# ..   ...     ...              ...               ...                   ...
# 561   66    Male             16.6               7.6                   315
# 562   66    Male             17.3               8.5                   388
# 563   64    Male              1.4               0.5                   298
# 571   90    Male              1.1               0.3                   215
# 578   60    Male              0.5               0.1                   500
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# ...

# %%
df2[df2.Age==df2.Age.max()]
# Out:
#      Age Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 571   90   Male              1.1               0.3                   215
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 571                        46                         134             6.9
#
#      Albumin  Albumin_and_Globulin_Ratio  Dataset
# 571      3.0                         0.7        1

# %%
df2.Age.max()
# Out:
# 90

# %%
df2[['Age','Gender']][df2.Age>49].shape
# Out:
# (230, 2)

# %%
df2[['Age','Gender']][df2.Age>49]
# Out:
#      Age  Gender
# 0     65  Female
# 1     62    Male
# 2     62    Male
# 3     58    Male
# 4     72    Male
# ..   ...     ...
# 566   50  Female
# 567   52    Male
# 571   90    Male
# 578   60    Male
# 580   52    Male
#
# [230 rows x 2 columns]

# %% [markdown]
# ## to display multiple colums data
# ## df_name[[]][query_neded]

# %% [markdown]
# ## sorting in data framesM

# %%
df3=df2.sort_values('Age')

# %%
df3
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 271    4    Male              0.8               0.2                   460
# 265    4    Male              0.9               0.2                   348
# 218    6    Male              0.6               0.1                   289
# 480    7    Male              0.5               0.1                   352
# 199    7  Female             27.2              11.8                  1420
# ..   ...     ...              ...               ...                   ...
# 391   75    Male              0.9               0.2                   162
# 397   78    Male              1.0               0.3                   152
# 29    84  Female              0.7               0.2                   188
# 44    85  Female              1.0               0.3                   208
# 571   90    Male              1.1               0.3                   215
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# ...

# %% [markdown]
# ## to convert a datatype we use parse
# ex.df2=pd.read_csv['file_addres',parse_date=['doj']
